# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
random.uniform(0, 1)
# Out:
# 0.620574292307228

# %%
import math
from math import sqrt

# %% [markdown]
# sys for common line argument

# %%
import sys
print(sys.argv)
# Out:
# ['/home/marta/miniconda3/lib/python3.13/site-packages/ipykernel_launcher.py', '--f=/run/user/1000/jupyter/runtime/kernel-v3f73db45295763bbba5a3b89d58bf3790319fce2b.json']

# %%
N = sys.argv[1]

if not N.isdigit():
    print("N must be an integer")
    sys.exit(1)

n_inside = 0

# calculate pi and error

for i in range(int(N)):
    x = random.uniform(0, 1)
    y = random.uniform(0, 1)
    l = sqrt(x**2 + y**2)
    if l < 1:
        n_inside += 1

pi = 4 * n_inside / int(N)

# %%
import random
import math
from math import sqrt
import sys


def main():
    '''Estimate pi using the quarter circle method and bootstrap error estimation.'''
    pass
    
    if (len(sys.argv) != 3) or not sys.argv[1].isdigit() or not sys.argv[2].isdigit():
        print("Usage: python estimate_pi.py N N_bootstrap")  
        sys.exit(1)

    N = sys.argv[1]
    n_bootstrap = sys.argv[2]


    pi_values = bootstrap_pi(N, n_bootstrap)
    pi_mean, pi_std = error_bootstrap(pi_values)

    print(f"Estimated pi: {pi_mean:.6f} ± {pi_std:.6f}")


def bootstrap_pi(N, n_bootstrap):
    pi_values = []
    for _ in range(n_bootstrap):
        n_inside = 0
        for i in range(int(N)):
            x = random.uniform(0, 1)
            y = random.uniform(0, 1)
            l = sqrt(x**2 + y**2)
            if l < 1:
                n_inside += 1
        pi_values.append(4 * n_inside / int(N))
    return pi_values

def error_bootstrap(pi_values):
    pi_mean = sum(pi_values) / len(pi_values)
    pi_std = sqrt(sum((x - pi_mean) ** 2 for x in pi_values) / len(pi_values))
    return pi_mean, pi_std

if __name__ == "__main__":
    main(sys.argv[1])
# Out:
# ['/home/marta/miniconda3/lib/python3.13/site-packages/ipykernel_launcher.py', '--f=/run/user/1000/jupyter/runtime/kernel-v3f73db45295763bbba5a3b89d58bf3790319fce2b.json']
# N must be an integer

# %%
import random
import math
from math import sqrt
import sys


def main():

    N=100000
    n_inside = 0

    # calculate pi and error

    for i in range(int(N)):
        x = random.uniform(0, 1)
        y = random.uniform(0, 1)
        l = sqrt(x**2 + y**2)
        if l < 1:
            n_inside += 1

    pi = 4 * n_inside / int(N)
    print(pi)

if __name__ == "__main__":
    main()
# Out:
# 3.1424
